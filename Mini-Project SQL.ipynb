# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pymysql.cursors

# %matplotlib inline

# %%
db_connection = pymysql.connect(host='localhost', 
                                database='sql_project', 
                                user='root',
                                password='')

bookings = pd.read_sql('SELECT * FROM Bookings', con=db_connection)
bookings.head()
# Out:
#    bookid  facid  memid            starttime  slots
# 0       0      3      1  2012-07-03 11:00:00      2
# 1       1      4      1  2012-07-03 08:00:00      2
# 2       2      6      0  2012-07-03 18:00:00      2
# 3       3      7      1  2012-07-03 19:00:00      2
# 4       4      8      1  2012-07-03 10:00:00      1

# %%
facilities = pd.read_sql('SELECT * FROM Facilities', con=db_connection)
facilities
# Out:
#    facid             name  membercost  guestcost  initialoutlay  \
# 0      0   Tennis Court 1         5.0       25.0          10000
# 1      1   Tennis Court 2         5.0       25.0           8000
# 2      2  Badminton Court         0.0       15.5           4000
# 3      3     Table Tennis         0.0        5.0            320
# 4      4   Massage Room 1         9.9       80.0           4000
# 5      5   Massage Room 2         9.9       80.0           4000
# 6      6     Squash Court         3.5       17.5           5000
# 7      7    Snooker Table         0.0        5.0            450
# 8      8       Pool Table         0.0        5.0            400
#
#    monthlymaintenance
# 0                 200
# 1                 200
# 2                  50
# 3                  10
# 4                3000
# 5                3000
# 6                  80
# 7                  15
# 8                  15

# %%
members = pd.read_sql('SELECT * FROM Members', con=db_connection)
members
# Out:
#     memid            surname  firstname  \
# 0       0              GUEST      GUEST
# 1       1              Smith     Darren
# 2       2              Smith      Tracy
# 3       3             Rownam        Tim
# 4       4           Joplette     Janice
# 5       5            Butters     Gerald
# 6       6              Tracy     Burton
# 7       7               Dare      Nancy
# 8       8             Boothe        Tim
# 9       9           Stibbons     Ponder
# 10     10               Owen    Charles
# 11     11              Jones      David
# 12     12              Baker       Anne
# 13     13            Farrell     Jemima
# 14     14              Smith       Jack
# 15     15              Bader   Florence
# 16     16              Baker    Timothy
# 17     17             Pinker      David
# 18     20            Genting    Matthew
# 19     21          Mackenzie       Anna
# 20     22             Coplin       Joan
# 21     24             Sarwin  Ramnaresh
# ...

# %% [markdown]
# ### Q1: Some of the facilities charge a fee to members, but some do not. Please list the names of the facilities that do.

# %%
pd.read_sql('SELECT * FROM `Facilities` WHERE membercost > 0;', con=db_connection)
# Out:
#    facid            name  membercost  guestcost  initialoutlay  \
# 0      0  Tennis Court 1         5.0       25.0          10000
# 1      1  Tennis Court 2         5.0       25.0           8000
# 2      4  Massage Room 1         9.9       80.0           4000
# 3      5  Massage Room 2         9.9       80.0           4000
# 4      6    Squash Court         3.5       17.5           5000
#
#    monthlymaintenance
# 0                 200
# 1                 200
# 2                3000
# 3                3000
# 4                  80

# %% [markdown]
# ### Q2: How many facilities do not charge a fee to members?

# %%
pd.read_sql('SELECT * FROM `Facilities` WHERE membercost = 0;', con=db_connection)
# Out:
#    facid             name  membercost  guestcost  initialoutlay  \
# 0      2  Badminton Court         0.0       15.5           4000
# 1      3     Table Tennis         0.0        5.0            320
# 2      7    Snooker Table         0.0        5.0            450
# 3      8       Pool Table         0.0        5.0            400
#
#    monthlymaintenance
# 0                  50
# 1                  10
# 2                  15
# 3                  15

# %% [markdown]
# ### Q3: How can you produce a list of facilities that charge a fee to members, where the fee is less than 20% of the facility's monthly maintenance cost? Return the facid, facility name, member cost, and monthly maintenance of the facilities in question.

# %%
pd.read_sql('''
            SELECT facid, name, membercost, monthlymaintenance, membercost/(monthlymaintenance)*100 AS Percentage 
            FROM `Facilities`
            HAVING membercost/(monthlymaintenance)*100 < 20 AND membercost != 0;
            ''',
            con=db_connection)
# Out:
#    facid            name  membercost  monthlymaintenance  Percentage
# 0      0  Tennis Court 1         5.0                 200       2.500
# 1      1  Tennis Court 2         5.0                 200       2.500
# 2      4  Massage Room 1         9.9                3000       0.330
# 3      5  Massage Room 2         9.9                3000       0.330
# 4      6    Squash Court         3.5                  80       4.375

# %% [markdown]
# ### Q4: How can you retrieve the details of facilities with ID 1 and 5? Write the query without using the OR operator.

# %%
pd.read_sql('SELECT * FROM `Facilities` WHERE facid IN (1, 5);', con=db_connection)
# Out:
#    facid            name  membercost  guestcost  initialoutlay  \
# 0      1  Tennis Court 2         5.0       25.0           8000
# 1      5  Massage Room 2         9.9       80.0           4000
#
#    monthlymaintenance
# 0                 200
# 1                3000

# %% [markdown]
# ### Q5: How can you produce a list of facilities, with each labelled as 'cheap' or 'expensive', depending on if their monthly maintenance cost is more than 100? Return the name and monthly maintenance of the facilities in question.

# %%
pd.read_sql('''
            SELECT
                facid,
                name,
                membercost,
                guestcost,
                initialoutlay,
                monthlymaintenance,
                CASE
                    WHEN monthlymaintenance >= 100 THEN 'expensive'
                    ELSE 'cheap'
                END AS 'Expensive/Cheap'
            FROM `Facilities`;
            ''', 
            con=db_connection)
# Out:
#    facid             name  membercost  guestcost  initialoutlay  \
# 0      0   Tennis Court 1         5.0       25.0          10000
# 1      1   Tennis Court 2         5.0       25.0           8000
# 2      2  Badminton Court         0.0       15.5           4000
# 3      3     Table Tennis         0.0        5.0            320
# 4      4   Massage Room 1         9.9       80.0           4000
# 5      5   Massage Room 2         9.9       80.0           4000
# 6      6     Squash Court         3.5       17.5           5000
# 7      7    Snooker Table         0.0        5.0            450
# 8      8       Pool Table         0.0        5.0            400
#
#    monthlymaintenance Expensive/Cheap
# 0                 200       expensive
# 1                 200       expensive
# 2                  50           cheap
# 3                  10           cheap
# 4                3000       expensive
# 5                3000       expensive
# 6                  80           cheap
# ...

# %% [markdown]
# ### Q6: You'd like to get the first and last name of the last member(s) who signed up. Do not use the LIMIT clause for your solution.

# %%
pd.read_sql('SELECT * FROM Members WHERE memid = 37;', con=db_connection)
# Out:
#    memid surname firstname                         address  zipcode  \
# 0     37   Smith    Darren  3 Funktown, Denzington, Boston    66796
#
#         telephone recommendedby             joindate
# 0  (822) 577-3541                2012-09-26 18:08:45

# %% [markdown]
# ### Q7: How can you produce a list of all members who have used a tennis court? Include in your output the name of the court, and the name of the member formatted as a single column. Ensure no duplicate data, and order by the member name.

# %%
pd.read_sql('''
            SELECT 
                F.`name`,
                M.surname,
                M.firstname,
                B.starttime
            FROM Members AS M

            INNER JOIN Bookings AS B ON M.memid = B.memid
            LEFT JOIN Facilities AS F ON B.facid = F.facid

            WHERE F.facid IN (0, 1)

            ORDER BY M.surname;''', con=db_connection)
# Out:
#                name surname firstname            starttime
# 0    Tennis Court 2   Bader  Florence  2012-08-18 12:30:00
# 1    Tennis Court 2   Bader  Florence  2012-09-10 14:30:00
# 2    Tennis Court 2   Bader  Florence  2012-08-25 18:30:00
# 3    Tennis Court 1   Bader  Florence  2012-09-23 11:00:00
# 4    Tennis Court 2   Bader  Florence  2012-09-23 15:00:00
# 5    Tennis Court 2   Bader  Florence  2012-08-23 19:00:00
# 6    Tennis Court 2   Bader  Florence  2012-09-02 08:30:00
# 7    Tennis Court 2   Bader  Florence  2012-09-09 16:00:00
# 8    Tennis Court 2   Bader  Florence  2012-09-22 14:00:00
# 9    Tennis Court 2   Baker      Anne  2012-08-23 09:00:00
# 10   Tennis Court 1   Baker   Timothy  2012-08-28 17:30:00
# 11   Tennis Court 2   Baker      Anne  2012-09-01 19:00:00
# 12   Tennis Court 1   Baker   Timothy  2012-09-12 18:00:00
# 13   Tennis Court 2   Baker      Anne  2012-09-21 08:00:00
# 14   Tennis Court 2   Baker      Anne  2012-09-22 16:00:00
# ...

# %% [markdown]
# ### Q8: How can you produce a list of bookings on the day of 2012-09-14 which will cost the member (or guest) more than 30? Remember that guests have different costs to members (the listed costs are per half-hour 'slot'), and the guest user's ID is always 0. Include in your output the name of the facility, the name of the member formatted as a single column, and the cost. Order by descending cost, and do not use any subqueries.

# %%
pd.read_sql('''
            SELECT 
                M.memid,
                M.surname,
                M.firstname,
                F.`name`,
                F.guestcost

            FROM Members AS M

            INNER JOIN Bookings AS B ON M.memid = B.memid
            LEFT JOIN Facilities AS F ON B.facid = F.facid

            WHERE B.starttime LIKE '2012-09-14 %' AND F.guestcost >= 15 AND M.memid = 0;''', con=db_connection)
# Out:
#     memid surname firstname            name  guestcost
# 0       0   GUEST     GUEST  Tennis Court 1       25.0
# 1       0   GUEST     GUEST  Tennis Court 1       25.0
# 2       0   GUEST     GUEST  Tennis Court 2       25.0
# 3       0   GUEST     GUEST  Tennis Court 2       25.0
# 4       0   GUEST     GUEST  Massage Room 1       80.0
# 5       0   GUEST     GUEST  Massage Room 1       80.0
# 6       0   GUEST     GUEST  Massage Room 1       80.0
# 7       0   GUEST     GUEST  Massage Room 2       80.0
# 8       0   GUEST     GUEST    Squash Court       17.5
# 9       0   GUEST     GUEST    Squash Court       17.5
# 10      0   GUEST     GUEST    Squash Court       17.5

# %% [markdown]
# ### Q9: This time, produce the same result as in Q8, but using a subquery.

# %%
pd.read_sql('''
            SELECT 
                SUB.memid,
                SUB.firstname,
                SUB.surname,
                SUB.guestcost,
                SUB.name

            FROM (SELECT 
                    M.memid,
                    M.surname,
                    M.firstname,
                    F.guestcost,
                    F.`name`
                FROM Bookings AS B
                JOIN Facilities AS F ON B.facid = F.facid
                JOIN Members AS M ON B.memid = M.memid
                WHERE B.starttime LIKE '2012-09-14 %' AND F.guestcost >= 15 AND M.memid = 0) AS SUB

            ORDER BY SUB.guestcost DESC;
    ''', con=db_connection)
# Out:
#     memid firstname surname  guestcost            name
# 0       0     GUEST   GUEST       80.0  Massage Room 1
# 1       0     GUEST   GUEST       80.0  Massage Room 2
# 2       0     GUEST   GUEST       80.0  Massage Room 1
# 3       0     GUEST   GUEST       80.0  Massage Room 1
# 4       0     GUEST   GUEST       25.0  Tennis Court 1
# 5       0     GUEST   GUEST       25.0  Tennis Court 1
# 6       0     GUEST   GUEST       25.0  Tennis Court 2
# 7       0     GUEST   GUEST       25.0  Tennis Court 2
# 8       0     GUEST   GUEST       17.5    Squash Court
# 9       0     GUEST   GUEST       17.5    Squash Court
# 10      0     GUEST   GUEST       17.5    Squash Court

# %% [markdown]
# ### Q10: Produce a list of facilities with a total revenue less than 1000. The output of facility name and total revenue, sorted by revenue. Remember that there's a different cost for guests and members!

# %%
pd.read_sql('''
            SELECT 
                M.memid,
                M.firstname,
                M.surname,
                B.slots * F.membercost,
                B.slots * F.guestcost,
                F.`name`

            FROM Bookings AS B

            INNER JOIN Members AS M ON M.memid = B.memid
            INNER JOIN Facilities AS F ON F.facid = B.facid

            ORDER BY M.memid;''', con=db_connection)
# Out:
#       memid firstname     surname  B.slots * F.membercost  \
# 0         0     GUEST       GUEST                     7.0
# 1         0     GUEST       GUEST                     0.0
# 2         0     GUEST       GUEST                     7.0
# 3         0     GUEST       GUEST                    21.0
# 4         0     GUEST       GUEST                    14.0
# 5         0     GUEST       GUEST                    30.0
# 6         0     GUEST       GUEST                    15.0
# 7         0     GUEST       GUEST                    19.8
# 8         0     GUEST       GUEST                     7.0
# 9         0     GUEST       GUEST                    19.8
# 10        0     GUEST       GUEST                    19.8
# 11        0     GUEST       GUEST                     0.0
# 12        0     GUEST       GUEST                    15.0
# 13        0     GUEST       GUEST                     0.0
# 14        0     GUEST       GUEST                    21.0
# ...
